# %%
import numpy as np
from PIL import Image
import matplotlib as mp
import os

# %%
imagenames=os.listdir("flowers/resized amapolas/")
imagenames
# Out:
# ['1.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '2.jpg',
#  '20.jpg',
#  '21.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '3.jpg',
#  '30.jpg',
#  '31.jpg',
#  '32.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg']

# %%
for  i in imagenames:
    image=Image.open(r"flowers/resized amapolas/"+i)
  #  print(image)
    ar=np.array(image)
    result=ar.flatten()
   


for i in result:
    result[i]=result[i]//765
    print(result)
# Out:
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# [154 135 131 ...  47  65  41]
# ...
